# %% [markdown]
# # ATM assignment No:3  2019 _4_10
# Amount
#
# Welcome to Virtual Bank
# Press 1 for Withdraw Amount
# Press 2 for Amount Deposite
# Press 3 for Balance Inquiry
# Press 4 Exit
#
# command
# #print("----------------------------------------------------------------------------------------")
#
# command
#
# Withdraw  "Please Enter the amount to withdraw: "
#
# Amount   Withdraw:
# You do not have sufficient Amount to Withdraw!")
# Please deposite amount first.")
# Do you want to Deposite amount?")
#       ("Type 1 for Yes")        ("Type 2 for No")
#
#
#     Amount "Please Enter the amount to Deposite: "
#             Congratulation your Transaction has been completed succcufully"
#            Thank you for banking with us"
#         else:
#             Thank you for banking with us
#
#
#        Congratulation your Transaction has been completed succcufully
#         Remainging_Balance = Amount - Withdraw
#    Withdraw Amount: ", Withdraw)
#       Balance        : ", Remainging_Balance
#      Please count your cash before leaving ATM
#       Thank you for banking with us
#
# elif command
#     Deposite "Please Enter the amount to Deposite: "
#     print("----------------------------------------------------------------------------------------")
#     Current_Amount  Amount  Deposite
#    "Congratulation your Transaction has been completed succcufully"
#   "Your current amount :"
#     " Thank you for banking with us"
#
# elif command
#     "Your current amount :"
#     "Thank you for banking with us"
#
# elif command
#     print
# else:
#     print("----------------------------------------------------------------------------------------")
#     print("You enter wrong amount....")
#     print("Try it Again....")
#     print("----------------------------------------------------------------------------------------")

# %%
amount = 0

# %%
print("< ---- Welcome to Virtual Bank ---- >")
print("Press 1: For Withdraw Amount ")
print("Press 2: For Amount Deposit ")
print("Press 3: For Balance Inquiry ")
print("Press 4: For Exit")

select = int(input("\nPlease Press here: "))  # select one option

if select == 1:
    withdraw = int(input("Please Enter the amount to Withdraw: "))    
    if withdraw > amount:                # in case withdraw amount is greater than account balance,, enter if block
        print("You do not have sufficient Amount to Withdraw! ")
        print("Please deposite amount first. Do you want to Deposite amount?")
        op = int(input("Type 1 for Yes\nType 2 for No\n"))
        if op == 1:         # if you wanna deposit amount ,,
            amount = int(input("Please Enter the amount to Deposite: "))   # enter the amount u wanna deposit
            print("Congratulation you have deposited amount successfully :)")
            # the withdraw amount u entered, will be subtracted from the total amount now ,, and ur balance is updated
            amount = amount - withdraw     
            print("Your current amount :", amount) # will show u the total balance in ur account
            print("Please count your cash before leaving ATM.\nThank you for banking with us :)")
            print("Thank you for banking with us!") 
    elif withdraw < amount:     # in case ur withdraw amount is less than the total balance u have
        print("Congratulation your Transaction has been completed successfully :)")
         # the withdraw amount u entered, will be subtracted from the total amount now ,, and ur balance gets updated
        amount = amount - withdraw    
        print("Remaining Balance: ", amount) # shows balance
        print("Please count your cash before leaving ATM.\nThank you for banking with us :)")
        
    else:
        print("Please count your cash before leaving ATM.\nThank you for banking with us :)")
        print("Thank you for banking with us!") # Greetings
    
    
        
elif select == 2:
    amount += int(input("Please Enter the amount to Deposite: ")) # for depositing amount,, new amount will be updated "+="
    print("Congratulation you have deposited amount successfully :)")
    print("Your current amount :", amount) # ur new account balance get updated :)
    print("Thank you for banking with us! ")
    
elif select == 3:
    print("Your current amount :", amount) # shows how much money do u have
    print("Thank you for banking with us!")
    
elif select == 4:
    print("Phir Mulakaat Hogi Kabhi !!!") # haha .. means You will meet again !!

else:
    print("You entered something else. Kindly type anyone (1,2,3,4) ") # in case wrong input is given in the beginning
    print("Try it Again....")
# Out:
# < ---- Welcome to Virtual Bank ---- >
# Press 1: For Withdraw Amount
# Press 2: For Amount Deposit
# Press 3: For Balance Inquiry
# Press 4: For Exit
#
# Please Press here: 2
# Please Enter the amount to Deposite: 2
# Congratulation you have deposited amount successfully :)
# Your current amount : 12002
# Thank you for banking with us!
